# %% [markdown]
# ## Scraping Tweets

# %%
import tweepy
import pandas as pd
import matplotlib.pyplot as plt; plt.rcdefaults()
import matplotlib.dates as mdates
import numpy as np
import seaborn as sns


import nltk
#nltk.download('punkt')
#nltk.download('wordnet')
from nltk import sent_tokenize, word_tokenize
from nltk.stem.snowball import SnowballStemmer
from nltk.stem.wordnet import WordNetLemmatizer
from nltk.corpus import stopwords
import re  
import spacy
from collections import Counter

# %%
nlp = spacy.load('es_core_news_sm') #en_core_news_lg

# %%
# %run ./keys.ipynb

# %%
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth)

# %%
api.me().screen_name
# Out:
# 'emiliomantilla6'

# %%
my_timeline = api.home_timeline()

# %% [markdown]
# #### Scraping User's timeline tweets (new version):

# %%
# Code from https://github.com/codingforentrepreneurs/30-Days-of-Python/blob/master/tutorial-reference/Day%2021/3%20-%20My%20Timeline%20%26%20User%20Timeline.ipynb

#def extract_timeline_as_df(timeline_list):
#    columns = set()
#    allowed_types = [str, int]
#    tweets_data = []
#    for status in timeline_list:
#        status_dict = dict(vars(status))
#        keys = status_dict.keys()
#        single_tweet_data = {"user": status.user.screen_name, "author": status.author.screen_name}
#        for k in keys:
#            try:
#                v_type = type(status_dict[k])
#            except:
#                v_type = None
#            if v_type != None:
#                if v_type in allowed_types:
#                    single_tweet_data[k] = status_dict[k]
#                    columns.add(k)
#        tweets_data.append(single_tweet_data)


#    header_cols = list(columns)
#    header_cols.append("user")
#    header_cols.append('author')
#    df = pd.DataFrame(tweets_data, columns=header_cols)
#    return df

# %%
#user = api.get_user("MashiRafael")
#user_timeline = user.timeline()
#df3 = extract_timeline_as_df(user_timeline)
#df3

# %% [markdown]
# #### Scraping User's timeline tweets (old version):

# %%
cursor = tweepy.Cursor(api.user_timeline,id="MashiRafael",tweet_mode="extended").items(1)

# %%
#for i in cursor: #Not very informative
#    print(i)
    
for i in cursor: # To see available things you could extract from cursor object. e.g. text
    print(dir(i))

#for i in cursor:
#    print(i.retweet_count)
# Out:
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_api', '_json', 'author', 'contributors', 'coordinates', 'created_at', 'destroy', 'display_text_range', 'entities', 'favorite', 'favorite_count', 'favorited', 'full_text', 'geo', 'id', 'id_str', 'in_reply_to_screen_name', 'in_reply_to_status_id', 'in_reply_to_status_id_str', 'in_reply_to_user_id', 'in_reply_to_user_id_str', 'is_quote_status', 'lang', 'parse', 'parse_list', 'place', 'retweet', 'retweet_count', 'retweeted', 'retweeted_status', 'retweets', 'source', 'source_url', 'truncated', 'user']

# %%
# Taken from this link:
# https://www.youtube.com/watch?v=bNDRiaFyLrs

number_of_tweets =4000 #Change accordingly to pull latest number of tweets. Limit seems to be 3240
user = []
author = []
id_ = []
id_str = []
tweets = []
language = []
source = []
source_url = []
retweet_count = []
likes = []
time = []

for i in tweepy.Cursor(api.user_timeline, id="MashiRafael", tweet_mode="extended").items(number_of_tweets): #"extended"
    #tweets.append(i.text)
    user.append(i.user.screen_name)
    author.append(i.author.screen_name)
    id_.append(i.id)
    id_str.append(i.id_str)
    tweets.append(i.full_text)
    language.append(i.lang)
    source.append(i.source)
    source_url.append(i.source_url)
    retweet_count.append(i.retweet_count)
    likes.append(i.favorite_count)
    time.append(i.created_at)

# %%
df = pd.DataFrame({'user':user,'author':author,'id':id_,'id_str':id_str,
                   'tweets':tweets,'language':language,'source':source,'source_url':source_url,
                   'retweet_count':retweet_count,'likes':likes,'time':time})

# %%
df
# Out:
#              user       author                   id               id_str  \
# 0     MashiRafael  MashiRafael  1486469645897019400  1486469645897019400
# 1     MashiRafael  MashiRafael  1486433624866140163  1486433624866140163
# 2     MashiRafael  MashiRafael  1486416582914060290  1486416582914060290
# 3     MashiRafael  MashiRafael  1486415886609170436  1486415886609170436
# 4     MashiRafael  MashiRafael  1486413954737967105  1486413954737967105
# ...           ...          ...                  ...                  ...
# 3237  MashiRafael  MashiRafael  1454861081936023556  1454861081936023556
# 3238  MashiRafael  MashiRafael  1454857627620585476  1454857627620585476
# 3239  MashiRafael  MashiRafael  1454857080859414533  1454857080859414533
# 3240  MashiRafael  MashiRafael  1454855989975556099  1454855989975556099
# 3241  MashiRafael  MashiRafael  1454854311733825540  1454854311733825540
#
#                                                  tweets language  \
# 0     RT @relicheandres: BANCOCRACIA \n\n287 mil (do...       es
# 1                               https://t.co/Qii4tz3VZd      und
# 2     RT @MashiRafael: 🇪🇨🇪🇨🇪🇨\nNo fue casualidad. Fu...       es
# 3     RT @MashiRafael: 🇪🇨🇪🇨🇪🇨\nEcuatorianos:\nTomen ...       es
# 4     🇪🇨🇪🇨🇪🇨\nEsta es la verdad histórica, con DATOS...       es
# ...                                                 ...      ...
# 3237  Más humillación para el país por la evidente p...       es
# 3238  🇪🇨🇪🇨🇪🇨\nEsto es EXTREMADAMENTE grave. Las rese...       es
# 3239  🇪🇨🇪🇨🇪🇨\nSi no están obligados a regresar al pa...       es
# 3240  En la Sainte Chapelle de París, en mi avión pr...       es
# 3241  RT @pameaguirre1: LA FRONTERA NORTE SE QUEDA S...       es
#
#                   source                          source_url  retweet_count  \
# 0     Twitter for iPhone  http://twitter.com/download/iphone            177
# 1     Twitter for iPhone  http://twitter.com/download/iphone            236
# 2     Twitter for iPhone  http://twitter.com/download/iphone            439
# 3     Twitter for iPhone  http://twitter.com/download/iphone           1314
# 4     Twitter for iPhone  http://twitter.com/download/iphone            188
# ...                  ...                                 ...            ...
# 3237  Twitter for iPhone  http://twitter.com/download/iphone            335
# 3238  Twitter for iPhone  http://twitter.com/download/iphone            406
# 3239  Twitter for iPhone  http://twitter.com/download/iphone            638
# 3240  Twitter for iPhone  http://twitter.com/download/iphone            655
# 3241  Twitter for iPhone  http://twitter.com/download/iphone           1373
#
#       likes                time
# 0         0 2022-01-26 22:42:35
# 1       456 2022-01-26 20:19:27
# 2         0 2022-01-26 19:11:44
# 3         0 2022-01-26 19:08:58
# 4       293 2022-01-26 19:01:17
# ...     ...                 ...
# 3237    563 2021-10-31 17:21:26
# 3238    612 2021-10-31 17:07:43
# 3239   1175 2021-10-31 17:05:32
# 3240   2533 2021-10-31 17:01:12
# 3241      0 2021-10-31 16:54:32
#
# [3242 rows x 11 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3242 entries, 0 to 3241
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   user           3242 non-null   object
#  1   author         3242 non-null   object
#  2   id             3242 non-null   int64
#  3   id_str         3242 non-null   object
#  4   tweets         3242 non-null   object
#  5   language       3242 non-null   object
#  6   source         3242 non-null   object
#  7   source_url     3242 non-null   object
#  8   retweet_count  3242 non-null   int64
#  9   likes          3242 non-null   int64
#  10  time           3242 non-null   datetime64[ns]
# dtypes: datetime64[ns](1), int64(3), object(7)
# memory usage: 278.7+ KB

# %%
df['Hour'] = df['time'].dt.hour
df['Date'] = df['time'].dt.date
df['Date'] = pd.to_datetime(df['Date'])

# %%
#df.to_csv("RC_Tweets_02242021_05142021.csv")
#df.to_csv("RC_Tweets_05142021_05172021.csv")
#df.to_csv("RC_Tweets_03012021_05282021.csv")
#df.to_csv("RC_Tweets_05292021_06052021.csv")
#df.to_csv("RC_Tweets_06052021_06222021.csv")
df.to_csv("RC_Tweets_103121_012622.csv")

# %% [markdown]
# #### Read Saved CSV files and merge them

# %%
pd.set_option("display.max_colwidth",None)

# %%
df_rc = pd.read_csv("RC_Tweets_03012021_05282021.csv", index_col = 0)
#df_rc = df_rc.sort_values(by="time").reset_index(drop=True)

df_rc_2 = pd.read_csv("RC_Tweets_05292021_06052021.csv", index_col = 0)

df_rc_3 = pd.read_csv("RC_Tweets_06052021_06222021.csv", index_col = 0)

# %%
df_rc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3239 entries, 0 to 3238
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   user           3239 non-null   object
#  1   author         3239 non-null   object
#  2   id             3239 non-null   int64
#  3   id_str         3239 non-null   int64
#  4   tweets         3239 non-null   object
#  5   language       3239 non-null   object
#  6   source         3239 non-null   object
#  7   source_url     3239 non-null   object
#  8   retweet_count  3239 non-null   int64
#  9   likes          3239 non-null   int64
#  10  time           3239 non-null   object
#  11  Hour           3239 non-null   int64
#  12  Date           3239 non-null   object
# dtypes: int64(5), object(8)
# memory usage: 354.3+ KB

# %%
df_rc = pd.concat([df_rc,df_rc_2,df_rc_3])
df_rc = df_rc.sort_values(by="time").reset_index(drop=True)

# %%
df_rc
# Out:
#              user       author                   id               id_str  \
# 0     MashiRafael  MashiRafael  1366264288604794880  1366264288604794880
# 1     MashiRafael  MashiRafael  1366266068273164297  1366266068273164297
# 2     MashiRafael  MashiRafael  1366272190602235904  1366272190602235904
# 3     MashiRafael  MashiRafael  1366274061760925696  1366274061760925696
# 4     MashiRafael  MashiRafael  1366283831129563144  1366283831129563144
# ...           ...          ...                  ...                  ...
# 3870  MashiRafael  MashiRafael  1407353781843529730  1407353781843529730
# 3871  MashiRafael  MashiRafael  1407355132271075333  1407355132271075333
# 3872  MashiRafael  MashiRafael  1407377983103451147  1407377983103451147
# 3873  MashiRafael  MashiRafael  1407398402430849026  1407398402430849026
# 3874  MashiRafael  MashiRafael  1407399704376324100  1407399704376324100
#
#                                                                                                                                                                                                                                                                                                                  tweets  \
# 0                                                                                                                                                                          RT @dolarizacionEc: [FALSO] Las reservas mínimas de liquidez depositadas en el @BancoCentral_Ec, que además no son tan elevadas como dice L…
# 4               132      0  2021-03-01 07:07:04     7  2021-03-01 00:00:00
# ...             ...    ...                  ...   ...                  ...
# 3870            395    581  2021-06-22 15:04:23    15           2021-06-22
# 3871            657   1431  2021-06-22 15:09:45    15           2021-06-22
# 3872            227      0  2021-06-22 16:40:33    16           2021-06-22
# 3873            441    776  2021-06-22 18:01:41    18           2021-06-22
# 3874             65    248  2021-06-22 18:06:52    18           2021-06-22
#
# [3875 rows x 13 columns]

# %%
#df_rc['Hour'] = df_rc['time'].dt.hour
df_rc['time'] = df_rc['time'].astype('datetime64')
df_rc['Date'] = df_rc['time'].dt.date
df_rc['Date'] = pd.to_datetime(df_rc['Date'])

# %%
df_rc
# Out:
#              user       author                   id               id_str  \
# 0     MashiRafael  MashiRafael  1366264288604794880  1366264288604794880
# 1     MashiRafael  MashiRafael  1366266068273164297  1366266068273164297
# 2     MashiRafael  MashiRafael  1366272190602235904  1366272190602235904
# 3     MashiRafael  MashiRafael  1366274061760925696  1366274061760925696
# 4     MashiRafael  MashiRafael  1366283831129563144  1366283831129563144
# ...           ...          ...                  ...                  ...
# 3870  MashiRafael  MashiRafael  1407353781843529730  1407353781843529730
# 3871  MashiRafael  MashiRafael  1407355132271075333  1407355132271075333
# 3872  MashiRafael  MashiRafael  1407377983103451147  1407377983103451147
# 3873  MashiRafael  MashiRafael  1407398402430849026  1407398402430849026
# 3874  MashiRafael  MashiRafael  1407399704376324100  1407399704376324100
#
#                                                                                                                                                                                                                                                                                                                  tweets  \
# 0                                                                                                                                                                          RT @dolarizacionEc: [FALSO] Las reservas mínimas de liquidez depositadas en el @BancoCentral_Ec, que además no son tan elevadas como dice L…
# 1      Lasso MiENTE a los jóvenes. La reserva técnica de los bancos privados NO es 3 de 10, sino 5 de 100 (5%), esto es, unos $2.000 millones. TODO el resto de los $8.000 millones del BCE son fondos PÚBLICOS, que los tienen en Suiza como garantía de pago de deuda externa\n#LassoEsMoreno https://t.co/O1DL4fL7cV
# 2                                                                                                                                                                          RT @PoliticoRadical: .@Salud_Ec desde las 3am me ingresaron por emergencia con el diagnóstico de apendicitis en el Hospital Eugenio Espejo.…
# 3                                                                                                                       “Proyecto de privatización del BCE no defiende la dolarización, al contrario, la pone en inminente riesgo”. (Observatorio de la Dolarización) | https://t.co/Z41fmifwkS https://t.co/rCC0dSoB1z
# 4                                                                                                                                                                          RT @JGonzalezAlvear: Sin odio pero con memoria, para saber que el odio destruye, memoria para que las futuras generaciones sepan que el peo…
# ...                                                                                                                                                                                                                                                                                                                 ...
# 3870                        Esta semana audiencia caso “Caminito”, otra canallada más contra Pablo Romero, por no haber aceptado involucrarme en caso Balda, como le fue a proponer Santiago Cuesta.\nAquí el testimonio de Enrique Santiago, abogado español.\n#LosCorruptosSiempreFueronEllos https://t.co/qIslz5qjPw
# 3871   Moreno es de lo peor que ha parido nuestra América. Despreciado por todos. Pronto tendrá que enfrentar la justicia, porque además de incapaz, es corrupto.\nNi siquiera vale la pena sacarlo del anonimato en que lo tiene el basurero de la historia.😉\n#LosCorruptosSiempreFueronEllos https://t.co/zS0yMuennR
# 3872                                                                                                                                                                       RT @BancadaUNES: Ante inconstitucionalidades y agresiones a la soberanía, #LaBancadaDeLaEsperanza recuerda que la embajadora de Ecuador ant…
# 3873  La prensa corrupta hacía el ridículo con tal de “acusarnos” por uso de aviones. Comparen ahora.\n\nPD1 El “sepelio privado” eta de… ¡Fidel Castro!\n\nPD2 Lasso tiene todo el derecho de utilizar avión. La seguridad del presidente, incluyendo movilización, es una cuestión de Estado. https://t.co/ixtNeYeCgO
# 3874                                                                                                                                                                                                                                                                                                               *era
#
#      language              source                          source_url  \
# 0          es  Twitter for iPhone  http://twitter.com/download/iphone
# 1          es  Twitter for iPhone  http://twitter.com/download/iphone
# 2          es  Twitter for iPhone  http://twitter.com/download/iphone
# 3          es  Twitter for iPhone  http://twitter.com/download/iphone
# 4          es  Twitter for iPhone  http://twitter.com/download/iphone
# ...       ...                 ...                                 ...
# 3870       es  Twitter for iPhone  http://twitter.com/download/iphone
# 3871       es  Twitter for iPhone  http://twitter.com/download/iphone
# 3872       es  Twitter for iPhone  http://twitter.com/download/iphone
# 3873       es  Twitter for iPhone  http://twitter.com/download/iphone
# 3874      und  Twitter for iPhone  http://twitter.com/download/iphone
#
#       retweet_count  likes                time  Hour       Date
# 0              1532      0 2021-03-01 05:49:25     5 2021-03-01
# 1              2020   3214 2021-03-01 05:56:29     5 2021-03-01
# 2              1061      0 2021-03-01 06:20:49     6 2021-03-01
# 3               819   1430 2021-03-01 06:28:15     6 2021-03-01
# 4               132      0 2021-03-01 07:07:04     7 2021-03-01
# ...             ...    ...                 ...   ...        ...
# 3870            395    581 2021-06-22 15:04:23    15 2021-06-22
# 3871            657   1431 2021-06-22 15:09:45    15 2021-06-22
# 3872            227      0 2021-06-22 16:40:33    16 2021-06-22
# 3873            441    776 2021-06-22 18:01:41    18 2021-06-22
# 3874             65    248 2021-06-22 18:06:52    18 2021-06-22
#
# [3875 rows x 13 columns]

# %% [markdown]
# #### Split between tweets and retweets

# %%
rc_retweets = df_rc[df_rc.tweets.str.contains("RT")]
rc_retweets = rc_retweets.reset_index(drop=True)

rc_tweets = df_rc[~df_rc.tweets.str.contains("RT")]
rc_tweets = rc_tweets.reset_index(drop=True)

# %%
rc_retweets
# Out:
#              user       author                   id               id_str  \
# 0     MashiRafael  MashiRafael  1366264288604794880  1366264288604794880
# 1     MashiRafael  MashiRafael  1366272190602235904  1366272190602235904
# 2     MashiRafael  MashiRafael  1366283831129563144  1366283831129563144
# 3     MashiRafael  MashiRafael  1366288012267687946  1366288012267687946
# 4     MashiRafael  MashiRafael  1366289090774249472  1366289090774249472
# ...           ...          ...                  ...                  ...
# 2646  MashiRafael  MashiRafael  1407152768545140736  1407152768545140736
# 2647  MashiRafael  MashiRafael  1407346926312431637  1407346926312431637
# 1222    La prensa corrupta hacía el ridículo con tal de “acusarnos” por uso de aviones. Comparen ahora.\n\nPD1 El “sepelio privado” eta de… ¡Fidel Castro!\n\nPD2 Lasso tiene todo el derecho de utilizar avión. La seguridad del presidente, incluyendo movilización, es una cuestión de Estado. https://t.co/ixtNeYeCgO
# 1223                                                                                                                                                                                                                                                                                                                 *era
#
#      language              source                          source_url  \
# 0          es  Twitter for iPhone  http://twitter.com/download/iphone
# 1          es  Twitter for iPhone  http://twitter.com/download/iphone
# 2          es  Twitter for iPhone  http://twitter.com/download/iphone
# 3          es  Twitter for iPhone  http://twitter.com/download/iphone
# 4          es  Twitter for iPhone  http://twitter.com/download/iphone
# ...       ...                 ...                                 ...
# 1219       es  Twitter for iPhone  http://twitter.com/download/iphone
# 1220       es  Twitter for iPhone  http://twitter.com/download/iphone
# 1221       es  Twitter for iPhone  http://twitter.com/download/iphone
# 1222       es  Twitter for iPhone  http://twitter.com/download/iphone
# 1223      und  Twitter for iPhone  http://twitter.com/download/iphone
#
#       retweet_count  likes                time  Hour       Date
# 0              2020   3214 2021-03-01 05:56:29     5 2021-03-01
# 1               819   1430 2021-03-01 06:28:15     6 2021-03-01
# 2               704   1526 2021-03-01 10:39:33    10 2021-03-01
# 3              2314   4574 2021-03-01 14:53:22    14 2021-03-01
# 4              1886   4303 2021-03-01 15:00:31    15 2021-03-01
# ...             ...    ...                 ...   ...        ...
# 1219            347    638 2021-06-22 13:08:32    13 2021-06-22
# 1220            395    581 2021-06-22 15:04:23    15 2021-06-22
# 1221            657   1431 2021-06-22 15:09:45    15 2021-06-22
# 1222            441    776 2021-06-22 18:01:41    18 2021-06-22
# 1223             65    248 2021-06-22 18:06:52    18 2021-06-22
#
# [1224 rows x 13 columns]

# %%
rc_tweets.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1224 entries, 0 to 1223
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   user           1224 non-null   object
#  1   author         1224 non-null   object
#  2   id             1224 non-null   int64
#  3   id_str         1224 non-null   int64
#  4   tweets         1224 non-null   object
#  5   language       1224 non-null   object
#  6   source         1224 non-null   object
#  7   source_url     1224 non-null   object
#  8   retweet_count  1224 non-null   int64
#  9   likes          1224 non-null   int64
#  10  time           1224 non-null   datetime64[ns]
#  11  Hour           1224 non-null   int64
#  12  Date           1224 non-null   datetime64[ns]
# dtypes: datetime64[ns](2), int64(5), object(6)
# memory usage: 124.4+ KB

# %% [markdown]
# #### RC Tweets vs Retweets Across Time

# %%
# Layered Time Series:
time_tweets = pd.Series(data=rc_tweets.Date.value_counts(), index=rc_tweets['Date'])
time_tweets.plot(figsize=(16, 4), label="RC - Tweets", legend=True)

time_retweets = pd.Series(data=rc_retweets.Date.value_counts(), index=rc_retweets['Date'])
time_retweets.plot(figsize=(16, 4), label="RC - Retweets", legend=True)
plt.xticks(rotation=45)
plt.gca().xaxis.set_major_locator(mdates.DayLocator(interval=7))
plt.show()

# %% [markdown]
# Rafael Correa tuvo gran actividad en la red social Twitter al crear Tweets, tanto como compartir Retweets, durante la epoca de campaña electoral de segunda vuelta. Justamente, el día de elecciones y en el que se anunció al ganador de las elecciones presidenciales 2021, la actividad de RC disminuyó considerablemente en el contenido compartido, mas no tanto en el contenido creado (Tweets).

# %% [markdown]
# Analizaremos en un principio los tweets de Rafael Correa, y haremos una comparación rápida sobre el contenido de sus Retweets. Iremos de una persepectiva general del sentimiento y temas más frecuentes hasta comparar el periodo antes y después de las elecciones.

# %% [markdown]
# #### RC Tweets Descriptive Analysis - Understanding our Dataset

# %% [markdown]
# #### 1) RC Tweets - Likes vs Retweets Count

# %%
# Layered Time Series:
time_likes = pd.Series(data=rc_tweets.likes.values, index=rc_tweets['Date'])
time_likes.plot(figsize=(16, 4), label="RC Tweets - Likes", legend=True)

time_retweets_count = pd.Series(data=rc_tweets.retweet_count.values, index=rc_tweets['Date'])
time_retweets_count.plot(figsize=(16, 4), label="RC Tweets - Retweet Count", legend=True)
plt.xticks(rotation=45)
plt.gca().xaxis.set_major_locator(mdates.DayLocator(interval=7))
plt.show()

# %%
rc_tweets[rc_tweets['likes']>30000]['tweets']

# %% [markdown]
# #### 2) RC Tweets - With Different Languages

# %%
rc_tweets.language.value_counts()

# %%
rc_tweets[rc_tweets['language']=='und']

# %%
rc_tweets[rc_tweets['language']=='en']

# %%
rc_tweets[rc_tweets['language']=='fr']

# %%
rc_tweets[rc_tweets['language']=='pt']

# %%
rc_tweets[rc_tweets['language']=='tl']

# %%
rc_tweets[rc_tweets['language']=='eu']

# %%
rc_tweets[rc_tweets['language']=='ca']

# %%
rc_tweets[rc_tweets['language']=='hu']

# %% [markdown]
# Esta bien mantener los tweets de otros idiomas para analisis generales, aunque para analisis de sentimiento es mejor remover los tweets de otros idiomas que no sean "es" espanol

# %% [markdown]
# #### 3) RC Tweets - Source (Device)

# %%
rc_tweets.source.value_counts()

# %%
rc_tweets[rc_tweets['source']=='Twitter Web App']

# %%
df = rc_tweets

# %%
### Extract Entities Mentioned

tokens = nlp(''.join(str(df.tweets.tolist())))
items = [(entity.text,entity.label_) for entity in tokens.ents]
#items = [x.text for x in tokens.ents]
Counter(items).most_common(20)

# %% [markdown]
# RC Tweets son en su mayoria hablando sobre Andres Arauz, Ecuador, Moreno y Lasso. Que tiene sentido, ya que Moreno ha sido el presidente saliente (aun presidente dentro del periodo de esta data), Lasso es el presidente entrante y anteriormente candidato a la presidencia. Y, Andres Arauz es el candidato a presidencia por parte del partido de RC. Lastimosamente, muchas de las entidades que deben ser clasificados como PERsonas, son clasificados incorrectamente, asi que algun analisis por entidades no seria el mas preciso.

# %%
#### Sum the number of tokens in each Doc
rc_tweets['num_tokens'] = [len(token) for token in rc_tweets.doc]
# Visualize histogram of tokens per tweet
g = sns.distplot(rc_tweets.num_tokens)

# %%
### Extract Most Frequent Hashtags

#s="@csfiguer @06Jerick Es fácil: hagamos una Comisión de la Verdad utilizando a Naciones Unidas (se han hecho más de 40).\nVeremos quiénes son los verdaderos ladrones, si es verdad tantas tonterías de la prensa, y si Contraloría y “juicios” no fueron el más puro lawfare.\n#LosCorruptosSiempreFueronEllos"
#[i  for i in s.split() if i.startswith("#") ]
text = df['tweets']


def extract_hashtags(text):
    text_lower = text.lower()
    allMatch = [i for i in text_lower.split() if i.startswith("#")]
    return allMatch

df['hashtags'] = text.apply(extract_hashtags)

# %%
df

# %%
df.hashtags.value_counts()

# %%
### Extract Top Words Overall

# %% [markdown]
# ### Sentiment Analysis of Tweets

# %% [markdown]
# #### Whole period

# %%
#This splits all the sentences up which makes it easier for us to work with

all_sentences = []

for word in rc_tweets['tweets']:
    all_sentences.append(word)

all_sentences
#df1 = df.to_string()

#df_split = df1.split()

#df_split
lines = list()
for line in all_sentences:    
    words = line.split()
    for w in words: 
       lines.append(w)


print(lines)

# %%
#Removing Punctuation

lines = [re.sub(r'[^A-Za-z0-9]+', '', x) for x in lines]

lines

lines2 = []

for word in lines:
    if word != '':
        lines2.append(word)

# %%
#This is stemming the words to their root
from nltk.stem.snowball import SnowballStemmer

# The Snowball Stemmer requires that you pass a language parameter
s_stemmer = SnowballStemmer(language='spanish')

stem = []
for word in lines2:
    stem.append(s_stemmer.stem(word))
    
stem

# %%
nlp.Defaults.stop_words

# %%
#Removing all Stop Words

stem2 = []

for word in stem:
    if word not in nlp.Defaults.stop_words:
        stem2.append(word)

stem2

# %%
df = pd.DataFrame(stem2)

df = df[0].value_counts()

#df
#df['freq'] = df.groupby(0)[0].transform('count')
#df['freq'] = df.groupby(0)[0].transform('count')
#df.sort_values(by = ('freq'), ascending=False)

# %%
#This will give frequencies of our words

from nltk.probability import FreqDist

freqdoctor = FreqDist()

for words in df:
    freqdoctor[words] += 1

freqdoctor

# %%
#This is a simple plot that shows the top 20 words being used
#df.plot(20)

df = df[:20,]
plt.figure(figsize=(10,5))
sns.barplot(df.values, df.index, alpha=0.8)
plt.title('Top Words Overall')
plt.ylabel('Word from Tweet', fontsize=12)
plt.xlabel('Count of Words', fontsize=12)
plt.show()

# %%
rc_tweets_1 = rc_tweets[(rc_tweets['Date']>="2021-02-24") &
                       (rc_tweets['Date']<="2021-03-16")]

df_1 = df[(df['Date']>="2021-02-24") &
                       (df['Date']<="2021-03-16")]


tweets_df = rc_tweets_1 #df #rc_retweets

# Create figure and plot space
fig, ax = plt.subplots(figsize=(12, 12))

# Add x-axis and y-axis
ax.scatter(tweets_df.Date,
       tweets_df.Hour,
       color='purple')

# Rotate and align the tick labels so they look better.
fig.autofmt_xdate()
# Set title and labels for axes
plt.yticks(np.arange(0, 23+1, 1.0))
#plt.xticks(np.arange(int("2021-02-24"), int("2021-03-09"), 1.0))
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))
plt.gca().xaxis.set_major_locator(mdates.DayLocator(interval=1))
ax.set(xlabel="Date",
       ylabel="Time of Day (Hour)",
       title="Daily Tweets by Hour\nFeb24 - Mar17 2021 for RC")
plt.grid()

plt.show()

# %%
#mostlike = df.loc[df.likes.nlargest(5).index]

# %%
#mostlike

# %% [markdown]
# #### Scraping tweets by keyword(# hasghtag):

# %%
cursor = tweepy.Cursor(api.search, q="Bitcoin",tweet_mode="extender").items(1)

# %%
#for i in cursor: #Not very informative
#    print(i)
    
#for i in cursor: # To see available things you could extract from cursor object. e.g. text
#    print(dir(i))

for i in cursor:
    print(i.text)
